# %%
import os
import numpy as np
import random
import torch
import time
import optuna
from pathlib import Path
from DQN.train_dqn import train_dqn
from envs.GraphEnv.impnode import ImpnodeEnv
from DQN import DQN_agent_modular
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# cuda

# %%
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

# %%
# variables for training the agent

num_train_eps = 100000 #10000 number training episodes to run
num_mem_fill_eps = 100#1000 number of episodes to run to initialize the memory
discount = 0.99 # gamma used for computing return
batch_size = 64 # number of transitions to sample from replay buffer for each learn step
mem_capacity = 50000  # 500000 size of the memory buffer
update_frequency = 500 #1000 number of interactions after which the target buffer is updated
eps_max = 1.0 # initial epsilon value
eps_min = 0.05 # final epsilon value
eps_step = 5000 #1000 amount by which epsilon is decayed at each episode
lr = 0.0001 # learning rate for the network
alpha = 0.001 # weighing factor for graph reconstruction loss
val_step = 1000
patience = 20
gnn_depth=4
state_size=2
hidden_size1=32
hidden_size2=64
action_size=1
n_step=3

num_nodes = (30, 50)
anc = 'dw_nd'
g_type = None
train_data_path = 'data/synthetic_small_dataset/PG_30_50'
train_data_path = Path.cwd()/train_data_path
val_data_path = 'data/synthetic_small_dataset/PG_val_30_50'
val_data_path = Path.cwd()/val_data_path

model_name = 'model'

# %%
results_base_path_train = "results/hyp_search_pg_train/{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}".format(
                           device, alpha, num_train_eps, num_mem_fill_eps, discount, batch_size, mem_capacity, update_frequency, eps_max, eps_min, eps_step, lr, gnn_depth, state_size, hidden_size1, hidden_size2, action_size, n_step, num_nodes, anc, g_type)

if not os.path.exists(results_base_path_train):
    os.makedirs(results_base_path_train)
else:
    timestamp = time.strftime("%Y%m%d%H%M%S")
    new_directory = f"{results_base_path_train}_{timestamp}"
    os.makedirs(new_directory)
    results_base_path_train = new_directory
    print(f"Directory already exists. Created a new one: {new_directory}")
# Out:
# Directory already exists. Created a new one: results/hyp_search_pg_train/cuda_0.001_100000_100_0.99_64_50000_500_1.0_0.05_5000_0.0001_4_2_32_64_1_3_(30, 50)_dw_nd_None_20240428170139

# %%
env_train = ImpnodeEnv(anc=anc, 
                       g_type=g_type, 
                       num_nodes=num_nodes, 
                       mode='train',
                       data_path=train_data_path
                       )

# %%
# create the dqn_agent
dqn_agent_train = DQN_agent_modular.DQNAgent(device,
                                             alpha=alpha,
                                             gnn_depth=gnn_depth,
                                             state_size=state_size,
                                             hidden_size1=hidden_size1,
                                             hidden_size2=hidden_size2,
                                             action_size=action_size,
                                             discount=discount,
                                             eps_max=eps_max,
                                             eps_min=eps_min,
                                             eps_step=eps_step,
                                             memory_capacity=mem_capacity,
                                             lr=lr,
                                             mode='train')

# %%
train_dqn(env_train, dqn_agent_train, results_base_path_train, num_train_eps, num_mem_fill_eps, n_step, batch_size, update_frequency,train_data_path=train_data_path, val_data_path=val_data_path, model_name=model_name, val_step=val_step, patience=patience)
# Out:
# train avg score
# 	train avg score  	 (min:   -0.259, max:   -0.172, cur:   -0.249)
# val avg score
# 	val avg score    	 (min:   -0.257, max:   -0.217, cur:   -0.254)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 train_dqn(env_train, dqn_agent_train, results_base_path_train, num_train_eps, num_mem_fill_eps, n_step, batch_size, update_frequency,train_data_path=train_data_path, val_data_path=val_data_path, model_name=model_name, val_step=val_step, patience=patience)
#
# File C:\rituja_git\ma-rituja-pardhi\DQN\train_dqn.py:40, in train_dqn(env, agent, results_base_path, num_train_eps, num_mem_fill_eps, n_step, batch_size, update_frequency, val_data_path, train_data_path, model_name, val_step, patience)
#      38 while not done:
#      39     mask = info['node_action_mask']
# ---> 40     action = agent.select_action(state, mask)
#      42     next_state, reward, done, truncated, info = env.step(action)
#      44     state_history.append(state)
#
# File C:\rituja_git\ma-rituja-pardhi\DQN\DQN_agent_modular.py:135, in DQNAgent.select_action(self, state, mask)
#     133 # pick the action with maximum Q-value as per the policy Q-network
#     134 with torch.no_grad():
# --> 135     batch_of_state = self.preprocess_graphs([state]).to(self.device)
#     136     action = self.policy_net.forward(batch_of_state).squeeze(1)
#     138     action = action.to(self.device)
#
# File ~\.conda\envs\impnode-gpu\lib\site-packages\torch_geometric\data\data.py:360, in BaseData.to(self, device, non_blocking, *args)
#     355 def to(self, device: Union[int, str], *args: str,
#     356        non_blocking: bool = False):
#     357     r"""Performs tensor device conversion, either for all attributes or
#     358     only the ones given in :obj:`*args`.
#     359     """
# --> 360     return self.apply(
#     361         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# File ~\.conda\envs\impnode-gpu\lib\site-packages\torch_geometric\data\data.py:340, in BaseData.apply(self, func, *args)
#     336 r"""Applies the function :obj:`func`, either to all attributes or only
#     337 the ones given in :obj:`*args`.
#     338 """
#     339 for store in self.stores:
# --> 340     store.apply(func, *args)
#     341 return self
#
# File ~\.conda\envs\impnode-gpu\lib\site-packages\torch_geometric\data\storage.py:201, in BaseStorage.apply(self, func, *args)
#     197 r"""Applies the function :obj:`func`, either to all attributes or only
#     198 the ones given in :obj:`*args`.
#     199 """
#     200 for key, value in self.items(*args):
# --> 201     self[key] = recursive_apply(value, func)
#     202 return self
#
# File ~\.conda\envs\impnode-gpu\lib\site-packages\torch_geometric\data\storage.py:895, in recursive_apply(data, func)
#     893 def recursive_apply(data: Any, func: Callable) -> Any:
#     894     if isinstance(data, Tensor):
# --> 895         return func(data)
#     896     elif isinstance(data, torch.nn.utils.rnn.PackedSequence):
#     897         return func(data)
#
# File ~\.conda\envs\impnode-gpu\lib\site-packages\torch_geometric\data\data.py:361, in BaseData.to.<locals>.<lambda>(x)
#     355 def to(self, device: Union[int, str], *args: str,
#     356        non_blocking: bool = False):
#     357     r"""Performs tensor device conversion, either for all attributes or
#     358     only the ones given in :obj:`*args`.
#     359     """
#     360     return self.apply(
# --> 361         lambda x: x.to(device=device, non_blocking=non_blocking), *args)
#
# KeyboardInterrupt:

# %%
print('done')

# %% [markdown]
# # visualize train and val performance

# %%
path='results/hyp_search_ws_train/cuda_0.001_100000_100_0.99_64_50000_500_1.0_0.05_5000_0.0001_4_2_32_64_1_3_(30, 50)_dw_nd_small-world_20240423235040'
import pandas as pd
import matplotlib.pyplot as plt
out = pd.read_csv('{}/info.csv'.format(path))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 7))
ax1.set_ylabel('episode')
ax1.set_xlabel('train avg score')
ax2.set_xlabel('val avg score')
ax1.plot(out.ep_cnt, out.train_avg_score)
ax2.plot(out.ep_cnt, out.val_avg_score)
